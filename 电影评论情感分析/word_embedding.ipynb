# %% [markdown]
# # 1. 数据分析及任务要求
#
# ## 1.1 数据预处理
# 本章训练的是5-gram模型，表示在PaddlePaddle训练时，每条数据的前4个词用来预测第5个词。PaddlePaddle提供了对应PTB数据集的python包paddle.dataset.imikolov，自动做数据的下载与预处理，方便大家使用。
#
# 预处理会把数据集中的每一句话前后加上开始符号\<s>以及结束符号\<e>。然后依据窗口大小（本教程中为5），从头到尾每次向右滑动窗口并生成一条数据。
#
# 这里注意是三个关键点：<br>
# 1. 句间标记----\<s> and \<e>
# 2. 窗口大小 - 类似于cnn中的卷积核
# 3. 步长 - 每次窗口移动的长度，最终生成的数据条数为步长+1
#
# 最后，每个输入会按其单词次在字典里的位置，转化成整数的索引序列，作为PaddlePaddle的输入。
#
# ![avatar](https://githubraw.cdn.bcebos.com/PaddlePaddle/book/develop/04.word2vec/image/nnlm.png?raw=true)

# %% [markdown]
# # 2 编程实现
# ## 2.1 导入必要的包

# %%
import paddle as paddle
import paddle.fluid as fluid
import numpy as np
import six
import math
from __future__ import print_function

paddle.enable_static()

# %% [markdown]
# ## 2.2 准备数据

# %%
# 定义模型参数
embed_size = 32 # embedding 维度
hidden_size = 256 # 隐层大小
gram_size = 5 # 取词的窗口大小
pass_num  = 1 # 训练的轮数
batch_size = 128 # 每轮训练当中，每次run program所用到的样本量

# %%
# 加载字典，并且获取字典的长度
# embedding 中，需要用到dic_size，
word_dic  = paddle.dataset.imikolov.build_dict()
dic_size = len(word_dic)
# 2 搭建模型

# %%
#
train_reader = paddle.batch(
        paddle.dataset.imikolov.train(word_dic,gram_size),batch_size = batch_size
)

test_reader = paddle.batch(
        paddle.dataset.imikolov.test(word_dic,gram_size),batch_size = batch_size
)
# Out:
# C:\Users\Jaon\AppData\Local\Temp/ipykernel_4540/3912444491.py:3: DeprecationWarning:
# Warning:
# API "paddle.dataset.imikolov.train" is deprecated since 2.0.0, and will be removed in future versions. Please use "paddle.text.datasets.Imikolov" instead.
# reason: Please use new dataset API which supports paddle.io.DataLoader
#   paddle.dataset.imikolov.train(word_dic,gram_size),batch_size = batch_size
# C:\Users\Jaon\AppData\Local\Temp/ipykernel_4540/3912444491.py:7: DeprecationWarning:
# Warning:
# API "paddle.dataset.imikolov.test" is deprecated since 2.0.0, and will be removed in future versions. Please use "paddle.text.datasets.Imikolov" instead.
# reason: Please use new dataset API which supports paddle.io.DataLoader
#   paddle.dataset.imikolov.test(word_dic,gram_size),batch_size = batch_size

# %%
sample = next(train_reader())

# %%
word_dic
# Out:
# {b'the': 0,
#  b'<unk>': 1,
#  '<e>': 2,
#  '<s>': 3,
#  b'N': 4,
#  b'of': 5,
#  b'to': 6,
#  b'a': 7,
#  b'in': 8,
#  b'and': 9,
#  b"'s": 10,
#  b'for': 11,
#  b'that': 12,
#  b'$': 13,
#  b'is': 14,
#  b'it': 15,
#  b'said': 16,
#  b'on': 17,
#  b'at': 18,
#  b'by': 19,
#  b'as': 20,
#  b'from': 21,
#  b'million': 22,
#  b'with': 23,
#  b'mr.': 24,
#  b'was': 25,
#  b'be': 26,
#  b'its': 27,
#  b'are': 28,
#  b'he': 29,
#  b'but': 30,
#  b'has': 31,
#  b'an': 32,
#  b"n't": 33,
#  b'have': 34,
#  b'will': 35,
#  b'new': 36,
#  b'or': 37,
#  b'company': 38,
#  b'they': 39,
#  b'this': 40,
#  b'which': 41,
#  b'year': 42,
#  b'would': 43,
#  b'about': 44,
#  b'market': 45,
#  b'says': 46,
#  b'more': 47,
#  b'were': 48,
#  b'had': 49,
#  b'billion': 50,
#  b'his': 51,
#  b'their': 52,
#  b'up': 53,
#  b'one': 54,
#  b'u.s.': 55,
#  b'than': 56,
#  b'stock': 57,
#  b'who': 58,
#  b'been': 59,
#  b'some': 60,
#  b'also': 61,
#  b'other': 62,
#  b'share': 63,
#  b'not': 64,
#  b'we': 65,
#  b'corp.': 66,
#  b'when': 67,
#  b'if': 68,
#  b'shares': 69,
#  b'last': 70,
#  b'all': 71,
#  b'i': 72,
#  b'president': 73,
#  b'years': 74,
#  b'trading': 75,
#  b'first': 76,
#  b'two': 77,
#  b'after': 78,
#  b'because': 79,
#  b'could': 80,
#  b'inc.': 81,
#  b'sales': 82,
#  b'out': 83,
#  b'&': 84,
#  b'there': 85,
#  b'only': 86,
#  b'business': 87,
#  b'do': 88,
#  b'such': 89,
#  b'can': 90,
#  b'york': 91,
#  b'most': 92,
#  b'into': 93,
#  b'co.': 94,
#  b'over': 95,
#  b'may': 96,
#  b'group': 97,
#  b'many': 98,
#  b'now': 99,
#  b'companies': 100,
#  b'federal': 101,
#  b'time': 102,
#  b'no': 103,
#  b'government': 104,
#  b'so': 105,
#  b'bank': 106,
#  b'cents': 107,
#  b'any': 108,
#  b'prices': 109,
#  b'you': 110,
#  b'exchange': 111,
#  b'quarter': 112,
#  b'price': 113,
#  b'yesterday': 114,
#  b'investors': 115,
#  b'down': 116,
#  b'people': 117,
#  b'what': 118,
#  b'even': 119,
#  b'say': 120,
#  b'rose': 121,
#  b'while': 122,
#  b'much': 123,
#  b'under': 124,
#  b'months': 125,
#  b'securities': 126,
#  b'week': 127,
#  b'big': 128,
#  b'them': 129,
#  b'bonds': 130,
#  b'interest': 131,
#  b'major': 132,
#  b'three': 133,
#  b'net': 134,
#  b'next': 135,
#  b'stocks': 136,
#  b"'": 137,
#  b'earnings': 138,
#  b'earlier': 139,
#  b'make': 140,
#  b'did': 141,
#  b'chairman': 142,
#  b'board': 143,
#  b'still': 144,
#  b'american': 145,
#  b'financial': 146,
#  b'state': 147,
#  b'just': 148,
#  b'through': 149,
#  b'investment': 150,
#  b'chief': 151,
#  b'before': 152,
#  b'since': 153,
#  b'executive': 154,
#  b'these': 155,
#  b'those': 156,
#  b'industry': 157,
#  b'money': 158,
#  b'national': 159,
#  b'program': 160,
#  b'made': 161,
#  b'rate': 162,
#  b'off': 163,
#  b'officials': 164,
#  b'like': 165,
#  b'expected': 166,
#  b'analysts': 167,
#  b'unit': 168,
#  b'she': 169,
#  b'house': 170,
#  b'days': 171,
#  b'month': 172,
#  b'profit': 173,
#  b'does': 174,
#  b'markets': 175,
#  b'rates': 176,
#  b'against': 177,
#  b'plan': 178,
#  b'sell': 179,
#  b'japanese': 180,
#  b'buy': 181,
#  b'both': 182,
#  b'income': 183,
#  b'capital': 184,
#  b'between': 185,
#  b'firm': 186,
#  b'recent': 187,
#  b'revenue': 188,
#  b'average': 189,
#  b'back': 190,
#  b'get': 191,
#  b'general': 192,
#  b'funds': 193,
#  b'during': 194,
#  b'products': 195,
#  b'issue': 196,
#  b'offer': 197,
#  b'ago': 198,
#  b'index': 199,
#  b'own': 200,
#  b'international': 201,
#  b'fell': 202,
#  b'should': 203,
#  b'well': 204,
#  b'friday': 205,
#  b'debt': 206,
#  b'higher': 207,
#  b'another': 208,
#  b'part': 209,
#  b'including': 210,
#  b'then': 211,
#  b'among': 212,
#  b'take': 213,
#  b'her': 214,
#  b'japan': 215,
#  b'reported': 216,
#  b'trade': 217,
#  b'each': 218,
#  b'being': 219,
#  b'according': 220,
#  b'world': 221,
#  b'court': 222,
#  b'however': 223,
#  b'sale': 224,
#  b'work': 225,
#  b'operations': 226,
#  b'lower': 227,
#  b'our': 228,
#  b'tax': 229,
#  b'plans': 230,
#  b'vice': 231,
#  b'past': 232,
#  b'traders': 233,
#  b'way': 234,
#  b'computer': 235,
#  b'sold': 236,
#  b'closed': 237,
#  b'high': 238,
#  b'end': 239,
#  b'bid': 240,
#  b'banks': 241,
#  b'several': 242,
#  b'department': 243,
#  b'growth': 244,
#  b'loss': 245,
#  b'economic': 246,
#  b'issues': 247,
#  b'common': 248,
#  b'increase': 249,
#  b'report': 250,
#  b'how': 251,
#  b'less': 252,
#  b'where': 253,
#  b'day': 254,
#  b'very': 255,
#  b'yield': 256,
#  b'good': 257,
#  b'pay': 258,
#  b'foreign': 259,
#  b'insurance': 260,
#  b'early': 261,
#  b'bill': 262,
#  b'five': 263,
#  b'few': 264,
#  b'management': 265,
#  b'third': 266,
#  b'bush': 267,
#  b'cash': 268,
#  b'used': 269,
#  b'costs': 270,
#  b'futures': 271,
#  b'might': 272,
#  b'due': 273,
#  b'use': 274,
#  b'oil': 275,
#  b'yen': 276,
#  b"'re": 277,
#  b'bond': 278,
#  b'public': 279,
#  b'current': 280,
#  b'director': 281,
#  b'treasury': 282,
#  b'concern': 283,
#  b'office': 284,
#  b'late': 285,
#  b'based': 286,
#  b'street': 287,
#  b'system': 288,
#  b'small': 289,
#  b'far': 290,
#  b'law': 291,
#  b'him': 292,
#  b'officer': 293,
#  b'spokesman': 294,
#  b'added': 295,
#  b'assets': 296,
#  b'too': 297,
#  b'congress': 298,
#  b'fund': 299,
#  b'least': 300,
#  b'already': 301,
#  b'close': 302,
#  b'agency': 303,
#  b'value': 304,
#  b'city': 305,
#  b'wall': 306,
#  b'contract': 307,
#  b'number': 308,
#  b'british': 309,
#  b'operating': 310,
#  b'agreement': 311,
#  b'ended': 312,
#  b'union': 313,
#  b'california': 314,
#  b'case': 315,
#  b'oct.': 316,
#  b'until': 317,
#  b'real': 318,
#  b'today': 319,
#  b'little': 320,
#  b'news': 321,
#  b'san': 322,
#  b'going': 323,
#  b'home': 324,
#  b'think': 325,
#  b'same': 326,
#  b'services': 327,
#  b'research': 328,
#  b'stake': 329,
#  b'dollar': 330,
#  b'september': 331,
#  b'help': 332,
#  b'though': 333,
#  b'agreed': 334,
#  b'service': 335,
#  b'move': 336,
#  b'second': 337,
#  b'put': 338,
#  b'maker': 339,
#  b'called': 340,
#  b'results': 341,
#  b'here': 342,
#  b'period': 343,
#  b'points': 344,
#  b'long': 345,
#  b'firms': 346,
#  b'total': 347,
#  b'buying': 348,
#  b'four': 349,
#  b'problems': 350,
#  b'loans': 351,
#  b'power': 352,
#  b'see': 353,
#  b'want': 354,
#  b'offering': 355,
#  b'point': 356,
#  b'without': 357,
#  b'economy': 358,
#  b'former': 359,
#  b'six': 360,
#  b'administration': 361,
#  b'analyst': 362,
#  b'third-quarter': 363,
#  b'corporate': 364,
#  b'credit': 365,
#  b'cost': 366,
#  b'production': 367,
#  b'selling': 368,
#  b'around': 369,
#  b'compared': 370,
#  b'monday': 371,
#  b'ual': 372,
#  b'west': 373,
#  b'set': 374,
#  b'although': 375,
#  b'control': 376,
#  b'losses': 377,
#  b'whether': 378,
#  b'go': 379,
#  b'half': 380,
#  b'recently': 381,
#  b'country': 382,
#  b'increased': 383,
#  b'volume': 384,
#  b'likely': 385,
#  b'annual': 386,
#  b'right': 387,
#  b'notes': 388,
#  b'further': 389,
#  b'old': 390,
#  b'continue': 391,
#  b'large': 392,
#  b'committee': 393,
#  b'dow': 394,
#  b'london': 395,
#  b'policy': 396,
#  b'cut': 397,
#  b'john': 398,
#  b'soviet': 399,
#  b'yet': 400,
#  b'life': 401,
#  b'august': 402,
#  b'strong': 403,
#  b'declined': 404,
#  b'political': 405,
#  b'my': 406,
#  b'gain': 407,
#  b'takeover': 408,
#  b'expects': 409,
#  b'held': 410,
#  b'must': 411,
#  b'plant': 412,
#  b'systems': 413,
#  b'fiscal': 414,
#  b'judge': 415,
#  b'paper': 416,
#  b'nov.': 417,
#  b'times': 418,
#  b'weeks': 419,
#  b'composite': 420,
#  b'industrial': 421,
#  b'result': 422,
#  b'largest': 423,
#  b'making': 424,
#  b'wo': 425,
#  b'announced': 426,
#  b'change': 427,
#  b'decline': 428,
#  b'come': 429,
#  b'white': 430,
#  b'inc': 431,
#  b'jones': 432,
#  b'problem': 433,
#  b'support': 434,
#  b'association': 435,
#  b'drop': 436,
#  b'certain': 437,
#  b'francisco': 438,
#  b'south': 439,
#  b'demand': 440,
#  b'workers': 441,
#  b'become': 442,
#  b'chicago': 443,
#  b'businesses': 444,
#  b'nearly': 445,
#  b'orders': 446,
#  b'air': 447,
#  b'record': 448,
#  b'senior': 449,
#  b'give': 450,
#  b'series': 451,
#  b'took': 452,
#  b'latest': 453,
#  b'members': 454,
#  b'priced': 455,
#  b'commission': 456,
#  b'development': 457,
#  b'employees': 458,
#  b'junk': 459,
#  b'line': 460,
#  b'acquisition': 461,
#  b'earthquake': 462,
#  b'trust': 463,
#  b'estate': 464,
#  b'area': 465,
#  b'example': 466,
#  b'official': 467,
#  b'estimated': 468,
#  b'later': 469,
#  b'loan': 470,
#  b'better': 471,
#  b'data': 472,
#  b'paid': 473,
#  b'commercial': 474,
#  b'ms.': 475,
#  b'deal': 476,
#  b'holding': 477,
#  b'meeting': 478,
#  b'executives': 479,
#  b'senate': 480,
#  b'your': 481,
#  b'despite': 482,
#  b'need': 483,
#  b'technology': 484,
#  b'purchase': 485,
#  b'rise': 486,
#  b'show': 487,
#  b'building': 488,
#  b'health': 489,
#  b'know': 490,
#  b'possible': 491,
#  b'proposal': 492,
#  b'level': 493,
#  b'offered': 494,
#  b'proposed': 495,
#  b'texas': 496,
#  b'almost': 497,
#  b'nine': 498,
#  b'comment': 499,
#  b'nation': 500,
#  b'others': 501,
#  b'return': 502,
#  b'currently': 503,
#  b'once': 504,
#  b'tuesday': 505,
#  b'spending': 506,
#  b'us': 507,
#  b'addition': 508,
#  b'investor': 509,
#  b'began': 510,
#  b'ford': 511,
#  b'october': 512,
#  b'robert': 513,
#  b'customers': 514,
#  b'within': 515,
#  b'future': 516,
#  b'order': 517,
#  b'product': 518,
#  b'terms': 519,
#  b'top': 520,
#  b'washington': 521,
#  b'amount': 522,
#  b'came': 523,
#  b'changes': 524,
#  b'damage': 525,
#  b'include': 526,
#  b'division': 527,
#  b'every': 528,
#  b'position': 529,
#  b'named': 530,
#  b'often': 531,
#  b'received': 532,
#  b'charge': 533,
#  b'east': 534,
#  b'equipment': 535,
#  b'expect': 536,
#  b'force': 537,
#  b'information': 538,
#  b'drug': 539,
#  b'gas': 540,
#  b'outstanding': 541,
#  b'private': 542,
#  b'defense': 543,
#  b'ltd.': 544,
#  b'options': 545,
#  b'america': 546,
#  b'gains': 547,
#  b'decision': 548,
#  b'dropped': 549,
#  b'trying': 550,
#  b'ca': 551,
#  b'lot': 552,
#  b'steel': 553,
#  b'united': 554,
#  b'filed': 555,
#  b'july': 556,
#  b'rights': 557,
#  b'again': 558,
#  b'enough': 559,
#  b'financing': 560,
#  b'told': 561,
#  b'never': 562,
#  b'tokyo': 563,
#  b'able': 564,
#  b'additional': 565,
#  b'europe': 566,
#  b'co': 567,
#  b'found': 568,
#  b'managers': 569,
#  b'european': 570,
#  b'industries': 571,
#  b'james': 572,
#  b'keep': 573,
#  b'banking': 574,
#  b'makes': 575,
#  b'buy-out': 576,
#  b'following': 577,
#  b'great': 578,
#  b'previous': 579,
#  b'provide': 580,
#  b'local': 581,
#  b'mortgage': 582,
#  b'transaction': 583,
#  b"'ve": 584,
#  b'corp': 585,
#  b'important': 586,
#  b'manager': 587,
#  b'programs': 588,
#  b'away': 589,
#  b'budget': 590,
#  b'computers': 591,
#  b'got': 592,
#  b'marketing': 593,
#  b'finance': 594,
#  b'car': 595,
#  b'equity': 596,
#  b'things': 597,
#  b'dollars': 598,
#  b'instead': 599,
#  b'best': 600,
#  b'consumer': 601,
#  b'fall': 602,
#  b'low': 603,
#  b'shareholders': 604,
#  b'fed': 605,
#  b'run': 606,
#  b'units': 607,
#  b'university': 608,
#  b'warner': 609,
#  b'continued': 610,
#  b'contracts': 611,
#  b'jaguar': 612,
#  b'whose': 613,
#  b'charges': 614,
#  b'food': 615,
#  b'lost': 616,
#  b'action': 617,
#  b'asked': 618,
#  b'construction': 619,
#  b'june': 620,
#  b'march': 621,
#  b'states': 622,
#  b'advertising': 623,
#  b'bills': 624,
#  b'soon': 625,
#  b'believe': 626,
#  b'posted': 627,
#  b'account': 628,
#  b'ad': 629,
#  b'below': 630,
#  b'claims': 631,
#  b'getting': 632,
#  b'sept.': 633,
#  b'auto': 634,
#  b'china': 635,
#  b'face': 636,
#  b'family': 637,
#  b'full': 638,
#  b'head': 639,
#  b'stores': 640,
#  b'above': 641,
#  b'place': 642,
#  b'potential': 643,
#  b'los': 644,
#  b'led': 645,
#  b'raise': 646,
#  b'black': 647,
#  b'gold': 648,
#  b'security': 649,
#  b'taken': 650,
#  b'fact': 651,
#  b'open': 652,
#  b'working': 653,
#  b'meanwhile': 654,
#  b'subsidiary': 655,
#  b'included': 656,
#  b'inflation': 657,
#  b'rather': 658,
#  b'restructuring': 659,
#  b'risk': 660,
#  b'special': 661,
#  b'boston': 662,
#  b'dealers': 663,
#  b'domestic': 664,
#  b'ibm': 665,
#  b'left': 666,
#  b'legal': 667,
#  b'bought': 668,
#  b'figures': 669,
#  b'suit': 670,
#  b'personal': 671,
#  b'tv': 672,
#  b'western': 673,
#  b'david': 674,
#  b'effort': 675,
#  b'holders': 676,
#  b'itself': 677,
#  b'look': 678,
#  b'via': 679,
#  b'mrs.': 680,
#  b'pacific': 681,
#  b'reports': 682,
#  b'airlines': 683,
#  b'd.': 684,
#  b'talks': 685,
#  b'using': 686,
#  b'approved': 687,
#  b'find': 688,
#  b'long-term': 689,
#  b'noted': 690,
#  b'probably': 691,
#  b'reached': 692,
#  b'statement': 693,
#  b'germany': 694,
#  b'along': 695,
#  b'previously': 696,
#  b'similar': 697,
#  b'countries': 698,
#  b'either': 699,
#  b'network': 700,
#  b'portfolio': 701,
#  b'available': 702,
#  b'center': 703,
#  b'individual': 704,
#  b'remain': 705,
#  b'secretary': 706,
#  b'#': 707,
#  b'calls': 708,
#  b'effect': 709,
#  b'hard': 710,
#  b'labor': 711,
#  b'reserve': 712,
#  b'biggest': 713,
#  b'dividend': 714,
#  b'performance': 715,
#  b'standard': 716,
#  b'cases': 717,
#  b'given': 718,
#  b'saying': 719,
#  b'groups': 720,
#  b'short': 721,
#  b'cars': 722,
#  b'efforts': 723,
#  b'increases': 724,
#  b'lawyers': 725,
#  b'school': 726,
#  b'canada': 727,
#  b'having': 728,
#  b'institute': 729,
#  b'known': 730,
#  b'parent': 731,
#  b'canadian': 732,
#  b'investments': 733,
#  b'looking': 734,
#  b'reduce': 735,
#  b'telephone': 736,
#  b'coming': 737,
#  b'magazine': 738,
#  b'makers': 739,
#  b'party': 740,
#  b'acquired': 741,
#  b'airline': 742,
#  b'approval': 743,
#  b'call': 744,
#  b'clients': 745,
#  b'energy': 746,
#  b'helped': 747,
#  b'payments': 748,
#  b'profits': 749,
#  b'went': 750,
#  b'gained': 751,
#  b'german': 752,
#  b'heavy': 753,
#  b'why': 754,
#  b'angeles': 755,
#  b'hit': 756,
#  b'north': 757,
#  b'savings': 758,
#  b'attorney': 759,
#  b'chemical': 760,
#  b'clear': 761,
#  b'manufacturing': 762,
#  b'slightly': 763,
#  b'strategy': 764,
#  b'columbia': 765,
#  b'leading': 766,
#  b'percentage': 767,
#  b'raised': 768,
#  b'team': 769,
#  b'transportation': 770,
#  b'act': 771,
#  b'different': 772,
#  b'directors': 773,
#  b'growing': 774,
#  b'lead': 775,
#  b'merrill': 776,
#  b'particularly': 777,
#  b'remains': 778,
#  b'bay': 779,
#  b'brokerage': 780,
#  b'eastern': 781,
#  b'failed': 782,
#  b'interests': 783,
#  b'joint': 784,
#  b'marks': 785,
#  b'project': 786,
#  b'television': 787,
#  b'william': 788,
#  b'year-earlier': 789,
#  b'britain': 790,
#  b'huge': 791,
#  b'institutions': 792,
#  b'machines': 793,
#  b'name': 794,
#  b'process': 795,
#  b'buyers': 796,
#  b'ever': 797,
#  b'hong': 798,
#  b'military': 799,
#  b'something': 800,
#  b'venture': 801,
#  b'activity': 802,
#  b'communications': 803,
#  b'completed': 804,
#  b'fees': 805,
#  b'free': 806,
#  b'includes': 807,
#  b'me': 808,
#  b'medical': 809,
#  b'question': 810,
#  b'estimates': 811,
#  b'legislation': 812,
#  b'levels': 813,
#  b'lines': 814,
#  b'view': 815,
#  b'lynch': 816,
#  b'michael': 817,
#  b'owns': 818,
#  b'rally': 819,
#  b'acquire': 820,
#  b'currency': 821,
#  b'especially': 822,
#  b'job': 823,
#  b'really': 824,
#  b'campaign': 825,
#  b'outside': 826,
#  b's&p': 827,
#  b'seeking': 828,
#  b'thing': 829,
#  b'toward': 830,
#  b'begin': 831,
#  b'holdings': 832,
#  b'leaders': 833,
#  b'reserves': 834,
#  b'limited': 835,
#  b'vote': 836,
#  b"'m": 837,
#  b'central': 838,
#  b'goods': 839,
#  b'related': 840,
#  b'bad': 841,
#  b'build': 842,
#  b'concerns': 843,
#  b'deficit': 844,
#  b'disclosed': 845,
#  b'hold': 846,
#  b'hours': 847,
#  b'kong': 848,
#  b'morgan': 849,
#  b'pressure': 850,
#  b'scheduled': 851,
#  b'started': 852,
#  b'taking': 853,
#  b'turn': 854,
#  b'wants': 855,
#  b'calif.': 856,
#  b'district': 857,
#  b'independent': 858,
#  b'means': 859,
#  b'role': 860,
#  b'adds': 861,
#  b'always': 862,
#  b'april': 863,
#  b'basis': 864,
#  b'leader': 865,
#  b'meet': 866,
#  b'poor': 867,
#  b'property': 868,
#  b'rep.': 869,
#  b'retail': 870,
#  b'seven': 871,
#  b'start': 872,
#  b'conference': 873,
#  b'course': 874,
#  b'estimate': 875,
#  b'involved': 876,
#  b'quickly': 877,
#  b'shearson': 878,
#  b'doing': 879,
#  b'fourth': 880,
#  b'impact': 881,
#  b'producers': 882,
#  b'rules': 883,
#  b'competition': 884,
#  b'daily': 885,
#  b'key': 886,
#  b'measure': 887,
#  b'try': 888,
#  b'turned': 889,
#  b'drexel': 890,
#  b'j.': 891,
#  b'largely': 892,
#  b'plants': 893,
#  b'reason': 894,
#  b'richard': 895,
#  b'seems': 896,
#  b'young': 897,
#  b'accounts': 898,
#  b'auction': 899,
#  b'care': 900,
#  b'crash': 901,
#  b'gm': 902,
#  b'man': 903,
#  b'needed': 904,
#  b'range': 905,
#  b'reduced': 906,
#  b'themselves': 907,
#  b"'ll": 908,
#  b'issued': 909,
#  b'majority': 910,
#  b'seen': 911,
#  b'test': 912,
#  b'allow': 913,
#  b'generally': 914,
#  b'longer': 915,
#  b'significant': 916,
#  b'ahead': 917,
#  b'aid': 918,
#  b'done': 919,
#  b'french': 920,
#  b'projects': 921,
#  b'staff': 922,
#  b'areas': 923,
#  b'beginning': 924,
#  b'brokers': 925,
#  b'december': 926,
#  b'partners': 927,
#  b'press': 928,
#  b'situation': 929,
#  b'stock-index': 930,
#  b'traded': 931,
#  b'consider': 932,
#  b'study': 933,
#  b'subject': 934,
#  b'supply': 935,
#  b'wednesday': 936,
#  b'caused': 937,
#  b'considered': 938,
#  b'journal': 939,
#  b'parts': 940,
#  b'paul': 941,
#  b'perhaps': 942,
#  b'plc': 943,
#  b'settlement': 944,
#  b'war': 945,
#  b'abortion': 946,
#  b'congressional': 947,
#  b'eight': 948,
#  b'housing': 949,
#  b'motor': 950,
#  b'night': 951,
#  b'planned': 952,
#  b'thought': 953,
#  b'volatility': 954,
#  b'community': 955,
#  b'de': 956,
#  b'near': 957,
#  b'nothing': 958,
#  b'plunge': 959,
#  b'anything': 960,
#  b'bankers': 961,
#  b'boost': 962,
#  b'electric': 963,
#  b'history': 964,
#  b'kind': 965,
#  b'let': 966,
#  b'men': 967,
#  b'protection': 968,
#  b'receive': 969,
#  b'short-term': 970,
#  b'showed': 971,
#  b'yields': 972,
#  b'a.': 973,
#  b'base': 974,
#  b'became': 975,
#  b'dec.': 976,
#  b'jumped': 977,
#  b'note': 978,
#  b'opened': 979,
#  b'prime': 980,
#  b'simply': 981,
#  b'taxes': 982,
#  b'thursday': 983,
#  b'changed': 984,
#  b'created': 985,
#  b'delivery': 986,
#  b'sharply': 987,
#  b'women': 988,
#  b'worth': 989,
#  b'active': 990,
#  b'convertible': 991,
#  b'democratic': 992,
#  b'form': 993,
#  b'george': 994,
#  b'manufacturers': 995,
#  b'produce': 996,
#  b'session': 997,
#  b'smaller': 998,
#  b'space': 999,
#  ...}

# %%
sample[0]
di = {y:x for x,y in word_dic.items()}
se = ''
for i in sample[0]:
    se = se +' ' + di[i]
print(se)
# Out:
#  <s> <unk> <unk> <unk> <unk>

# %% [markdown]
# ## 2.3 定义模型结构的参数--训练轮数及超参等
# 1、更大的BATCH_SIZE将使得训练更快收敛，但也会消耗更多内存。<br/>
# 2、paddle不必再手动计算词向量。PaddlePaddle提供了一个内置的方法fluid.layers.embedding，我们就可以直接用它来构造 N-gram 神经网络。<br>
# 3、因为词向量比较稀疏，我们传入参数 is_sparse == True, 可以加速稀疏矩阵的更新。
# 本次学习模型如下：
# ![avatar](https://githubraw.cdn.bcebos.com/PaddlePaddle/book/develop/04.word2vec/image/ngram.png?raw=true)

# %%
# 定义N-gram 神经网络结构
def N_GramNet(words,is_sparse =True):
    embed_first = fluid.layers.embedding(
        input=words[0],
        size=[dic_size,embed_size],
        dtype='float32',
        is_sparse=is_sparse
    )

    embed_second = fluid.layers.embedding(
        input=words[1],
        size = [dic_size,embed_size],
        dtype='float32',
        is_sparse=is_sparse
    )

    embed_third = fluid.layers.embedding(
        input=words[2],
        size = [dic_size,embed_size],
        dtype='float32',
        is_sparse=is_sparse
    )

    embed_fourth = fluid.layers.embedding(
        input=words[3],
        size = [dic_size,embed_size],
        dtype='float32',
        is_sparse=is_sparse
    )

    # 词向量拼接
    contact_embed = fluid.layers.concat(
        input=[embed_first,embed_second,embed_third,embed_fourth],
        axis=1
    )

    hidden1 = fluid.layers.fc(
        input= contact_embed,
        size = hidden_size,
        act = 'sigmoid'
    )

    prediction = fluid.layers.fc(
        input=hidden1,size=dic_size,act = 'softmax' #词向量的长度
    )

    return prediction

# %%
# 定义数据
label = fluid.layers.data(name='label',shape=[1], dtype='int64')

word01 = fluid.layers.data(
    name = 'word_01',shape=[1],dtype = 'int64'
)
word02 = fluid.layers.data(
    name = 'word_02',shape=[1],dtype = 'int64'
)
word03 = fluid.layers.data(
    name = 'word_03',shape=[1],dtype = 'int64'
)
word04 = fluid.layers.data(
    name = 'word_04',shape=[1],dtype = 'int64'
)

# %% [markdown]
# ## 2.4 定义损失函数

# %%
def cost_func(prediction):
    # '输入数据'的定义必须要在inference_program的声明之后，
    # 否则train program输入数据的顺序就变成了[输入数据, firstw, secondw,
    # thirdw, fourthw], 这是不正确的.
    # 使用交叉熵
    cost = fluid.layers.cross_entropy(prediction,label=label)
    avg_cost = fluid.layers.mean(cost)
    return avg_cost

# %% [markdown]
# ## 2.5 定义优化方法

# %%
def optimizer_func():
    return fluid.optimizer.AdagradOptimizer(
        learning_rate=0.01
    )

# %% [markdown]
# # 2.6 模型组装

# %%
def train_model():
    # 定义输入数据
    word_list = [word01,word02,word03,word04]
    # 获取分类器
    prediction = N_GramNet(word_list)
    acc = fluid.layers.accuracy(prediction,label=label)
    avg_cost = cost_func(prediction)
    optimizer = optimizer_func()
    optimizer.minimize(avg_cost)
    # print(type(acc),type(avg_cost))
    return avg_cost,acc,prediction

# %%
avg_cost,acc ,prediction = train_model()

# %% [markdown]
# # 3. 模型训练

# %%
# 定义训练场所
use_cuda = False # 是否使用cpu，这里是否
place = fluid.CUDAPlace(0) if use_cuda else fluid.CPUPlace()

# 定义执行引擎
executor = fluid.Executor(place)

# 定义测试程序
test_program = fluid.default_main_program().clone(for_test=True)

#初始化模型
executor.run(fluid.default_startup_program())
# Out:
# []

# %%
feed_list = ['word_01','word_02','word_03','word_04','label']
feed_var_list = [
    fluid.default_main_program().global_block().var(var_name) for var_name in feed_list
]
feeder =fluid.DataFeeder(feed_list=feed_var_list,place=place)

# %%
for i in range(pass_num):
    #train
    j = 0
    for data in train_reader():

        train_acc,train_avg_cost = executor.run(
            fluid.default_main_program(),
            feed = feeder.feed(data),
            fetch_list=[acc,avg_cost]
        )
        j+=1
        if j%100 == 0:
            print('pass:{} ,iterator : {} ,acc is : {}, avg_cost is {}'.format(i,j,train_acc,train_avg_cost))

    # test
    j = 0
    for data in test_reader():
        test_acc, test_avg = executor.run(
            test_program,feed = feeder.feed(data),fetch_list=[acc,avg_cost]
        )
        j+=1
        if j%100 == 0:
            print('pass:{} ,iterator : {} ,acc is : {}, avg_cost is {}'.format(i,j,train_acc,train_avg_cost))
# Out:
# pass:0 ,iterator : 100 ,acc is : [0.09375], avg_cost is [5.461892]
# pass:0 ,iterator : 200 ,acc is : [0.140625], avg_cost is [5.1464887]
# pass:0 ,iterator : 300 ,acc is : [0.125], avg_cost is [5.0911307]
# pass:0 ,iterator : 400 ,acc is : [0.1484375], avg_cost is [5.161768]
# pass:0 ,iterator : 500 ,acc is : [0.1328125], avg_cost is [5.150032]
# pass:0 ,iterator : 600 ,acc is : [0.25], avg_cost is [4.1022882]
# pass:0 ,iterator : 700 ,acc is : [0.1875], avg_cost is [4.7641973]
# pass:0 ,iterator : 800 ,acc is : [0.140625], avg_cost is [4.6442866]
# pass:0 ,iterator : 900 ,acc is : [0.1484375], avg_cost is [5.2562394]
# pass:0 ,iterator : 1000 ,acc is : [0.15625], avg_cost is [5.1771727]
# pass:0 ,iterator : 1100 ,acc is : [0.125], avg_cost is [5.1837196]
# pass:0 ,iterator : 1200 ,acc is : [0.1171875], avg_cost is [5.4172225]
# pass:0 ,iterator : 1300 ,acc is : [0.2421875], avg_cost is [4.2972817]
# pass:0 ,iterator : 1400 ,acc is : [0.140625], avg_cost is [5.4707174]
# pass:0 ,iterator : 1500 ,acc is : [0.140625], avg_cost is [5.1672945]
# pass:0 ,iterator : 1600 ,acc is : [0.234375], avg_cost is [4.67078]
# pass:0 ,iterator : 1700 ,acc is : [0.2109375], avg_cost is [4.8806496]
# pass:0 ,iterator : 1800 ,acc is : [0.171875], avg_cost is [5.013206]
# pass:0 ,iterator : 1900 ,acc is : [0.1953125], avg_cost is [4.9255214]
# pass:0 ,iterator : 2000 ,acc is : [0.203125], avg_cost is [4.496975]
# pass:0 ,iterator : 2100 ,acc is : [0.2421875], avg_cost is [4.6951694]
# pass:0 ,iterator : 2200 ,acc is : [0.2421875], avg_cost is [4.1812134]
# pass:0 ,iterator : 2300 ,acc is : [0.1484375], avg_cost is [5.429207]
# pass:0 ,iterator : 2400 ,acc is : [0.125], avg_cost is [5.5820704]
# pass:0 ,iterator : 2500 ,acc is : [0.171875], avg_cost is [5.146492]
# pass:0 ,iterator : 2600 ,acc is : [0.203125], avg_cost is [5.130153]
# pass:0 ,iterator : 2700 ,acc is : [0.171875], avg_cost is [5.0624137]
# pass:0 ,iterator : 2800 ,acc is : [0.1953125], avg_cost is [5.0502853]
# pass:0 ,iterator : 2900 ,acc is : [0.1953125], avg_cost is [5.1529965]
# pass:0 ,iterator : 3000 ,acc is : [0.21875], avg_cost is [4.613473]
# pass:0 ,iterator : 3100 ,acc is : [0.2734375], avg_cost is [4.181878]
# pass:0 ,iterator : 3200 ,acc is : [0.25], avg_cost is [4.7076287]
# pass:0 ,iterator : 3300 ,acc is : [0.2109375], avg_cost is [5.0655594]
# pass:0 ,iterator : 3400 ,acc is : [0.09375], avg_cost is [5.7254047]
# pass:0 ,iterator : 3500 ,acc is : [0.125], avg_cost is [5.341038]
# pass:0 ,iterator : 3600 ,acc is : [0.1875], avg_cost is [5.237096]
# pass:0 ,iterator : 3700 ,acc is : [0.140625], avg_cost is [4.9418693]
# pass:0 ,iterator : 3800 ,acc is : [0.265625], avg_cost is [4.775509]
# pass:0 ,iterator : 3900 ,acc is : [0.1796875], avg_cost is [5.015642]
# pass:0 ,iterator : 4000 ,acc is : [0.2578125], avg_cost is [3.8993726]
# pass:0 ,iterator : 4100 ,acc is : [0.1484375], avg_cost is [5.1615076]
# pass:0 ,iterator : 4200 ,acc is : [0.125], avg_cost is [5.199663]
# pass:0 ,iterator : 4300 ,acc is : [0.140625], avg_cost is [5.253788]
# pass:0 ,iterator : 4400 ,acc is : [0.171875], avg_cost is [5.1671515]
# pass:0 ,iterator : 4500 ,acc is : [0.25], avg_cost is [4.3296022]
# pass:0 ,iterator : 4600 ,acc is : [0.265625], avg_cost is [4.3004327]
# pass:0 ,iterator : 4700 ,acc is : [0.1484375], avg_cost is [5.134981]
# pass:0 ,iterator : 4800 ,acc is : [0.15625], avg_cost is [5.262084]
# pass:0 ,iterator : 4900 ,acc is : [0.171875], avg_cost is [4.820284]
# pass:0 ,iterator : 5000 ,acc is : [0.1640625], avg_cost is [5.1802225]
# pass:0 ,iterator : 5100 ,acc is : [0.140625], avg_cost is [5.3646564]
# pass:0 ,iterator : 5200 ,acc is : [0.4453125], avg_cost is [3.773712]
# pass:0 ,iterator : 5300 ,acc is : [0.1796875], avg_cost is [5.0938296]
# pass:0 ,iterator : 5400 ,acc is : [0.171875], avg_cost is [5.5462656]
# pass:0 ,iterator : 5500 ,acc is : [0.1875], avg_cost is [4.791999]
# pass:0 ,iterator : 5600 ,acc is : [0.171875], avg_cost is [5.050256]
# pass:0 ,iterator : 5700 ,acc is : [0.2109375], avg_cost is [4.752738]
# pass:0 ,iterator : 5800 ,acc is : [0.171875], avg_cost is [4.854501]
# pass:0 ,iterator : 5900 ,acc is : [0.1640625], avg_cost is [5.357695]
# pass:0 ,iterator : 6000 ,acc is : [0.1953125], avg_cost is [4.746736]
# pass:0 ,iterator : 6100 ,acc is : [0.1484375], avg_cost is [4.9470553]
# pass:0 ,iterator : 6200 ,acc is : [0.1875], avg_cost is [4.694653]
# pass:0 ,iterator : 100 ,acc is : [0.21212122], avg_cost is [4.7347965]
# pass:0 ,iterator : 200 ,acc is : [0.21212122], avg_cost is [4.7347965]
# pass:0 ,iterator : 300 ,acc is : [0.21212122], avg_cost is [4.7347965]
# pass:0 ,iterator : 400 ,acc is : [0.21212122], avg_cost is [4.7347965]

# %%
# 保存模型
import os
model_dir = '../model/word_embedding.n_gram.model/'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

fluid.io.save_inference_model(
    model_dir,['word_01','word_02','word_03','word_04'],[prediction],executor
)
# Out:
# ['save_infer_model/scale_0.tmp_0']

# %%
# 保存模型
import os
model_dir = '../model/word_embedding.n_gram.model.params/'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

fluid.io.save_params(
    executor,model_dir,fluid.default_main_program()
)

# %%
exe = fluid.Executor(place)

# %%
import numpy

# %%
inference_scope = fluid.core.Scope()
with fluid.scope_guard(inference_scope):
    # 使用fluid.io.load_inference_model获取inference program，
    # feed变量的名称feed_target_names和从scope中fetch的对象fetch_targets
    [inferencer, feed_target_names,
        fetch_targets] = fluid.io.load_inference_model(model_dir, exe)

    data1 = numpy.asarray([[211,11]], dtype=numpy.int64)  # 'among'
    data2 = numpy.asarray([[6]], dtype=numpy.int64)  # 'a'
    data3 = numpy.asarray([[96]], dtype=numpy.int64)  # 'group'
    data4 = numpy.asarray([[4]], dtype=numpy.int64)  # 'of'

    lod = numpy.asarray([[1]], dtype=numpy.int64)

    first_word = fluid.create_lod_tensor(data1, lod, place)
    print(first_word.shape())
    # second_word = fluid.create_lod_tensor(data2, lod, place)
    # third_word = fluid.create_lod_tensor(data3, lod, place)
    # fourth_word = fluid.create_lod_tensor(data4, lod, place)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9444/1525465715.py in <module>
# ----> 1 inference_scope = fluid.core.Scope()
#       2 with fluid.scope_guard(inference_scope):
#       3     # 使用fluid.io.load_inference_model获取inference program，
#       4     # feed变量的名称feed_target_names和从scope中fetch的对象fetch_targets
#       5     [inferencer, feed_target_names,
#
# NameError: name 'fluid' is not defined
